# %%
import matplotlib.pyplot as plt

l = [1,3, 4, 2, 5, 8, 7, 6, 9, 10, 11, 12, 15, 28]

plot_values = [l]
plt.boxplot(plot_values)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

data = pd.read_excel("ESD.xlsx")
df = pd.DataFrame(data)

plt.boxplot(df['Annual Salary'])
plt.show()
